# %% [markdown]
# <a href="https://colab.research.google.com/github/23b2232/Iris_classification/blob/main/Iris_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
iris = pd.read_csv('IRIS.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# In this project I have tried to include different models and done them from scratch. Here I will be using KNN and Decision tree.

# %% [markdown]
# The following block is for the EDA.

# %%
iris.describe(include = 'all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width      species
# count     150.000000   150.000000    150.000000   150.000000          150
# unique           NaN          NaN           NaN          NaN            3
# top              NaN          NaN           NaN          NaN  Iris-setosa
# freq             NaN          NaN           NaN          NaN           50
# mean        5.843333     3.054000      3.758667     1.198667          NaN
# std         0.828066     0.433594      1.764420     0.763161          NaN
# min         4.300000     2.000000      1.000000     0.100000          NaN
# 25%         5.100000     2.800000      1.600000     0.300000          NaN
# 50%         5.800000     3.000000      4.350000     1.300000          NaN
# 75%         6.400000     3.300000      5.100000     1.800000          NaN
# max         7.900000     4.400000      6.900000     2.500000          NaN

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
fig, axes = plt.subplots(2, 2, figsize = (10, 10))
sns.histplot(x = 'sepal_length', hue='species', data = iris, ax = axes[0, 0])
sns.histplot(x = 'sepal_width', hue='species', data = iris, ax = axes[0, 1])
sns.histplot(x = 'petal_length', hue='species', data = iris, ax = axes[1, 0])
sns.histplot(x = 'petal_width', hue='species', data = iris, ax = axes[1, 1])
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize = (10, 10))
sns.boxplot(x='species', y = 'sepal_length', data = iris, ax = axes[0, 0])
sns.boxplot(x='species', y = 'sepal_width', data = iris, ax = axes[0, 1])
sns.boxplot(x='species', y = 'petal_length', data = iris, ax = axes[1, 0])
sns.boxplot(x='species', y = 'petal_width', data = iris, ax = axes[1, 1])
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize = (10, 10))
sns.violinplot(x='species', y = 'sepal_length', data = iris, ax = axes[0, 0])
sns.violinplot(x='species', y = 'sepal_width', data = iris, ax = axes[0, 1])
sns.violinplot(x='species', y = 'petal_length', data = iris, ax = axes[1, 0])
sns.violinplot(x='species', y = 'petal_width', data = iris, ax = axes[1, 1])
plt.tight_layout()
plt.show()

# %%
sns.heatmap(iris.corr(numeric_only=True), annot = True, cmap = 'coolwarm')
plt.show()

# %%
sns.pairplot(iris, hue = 'species', diag_kind='kde')
plt.show()
